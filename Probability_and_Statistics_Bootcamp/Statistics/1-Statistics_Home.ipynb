# %% [markdown]
# ## Statistics Home

# %%
### With Python use the NumPy library mean() method to find the mean of the values 4,11,7,14


import numpy as np

x = [4,11,7,14]

ans = np.mean(x)

print(ans)
# Out:
# 9.0
