# %% [markdown]
# ## SMOTE(Synthetic Minority Oversampling Technique)
#
# SMOTE (Synthetic Minority Over-sampling Technique) is a technique used in machine learning to address imbalanced datasets where the minority class has significantly fewer instances than the majority class. SMOTE involves generating synthetic instances of the minority class by interpolating between existing instances.

# %%
from sklearn.datasets import make_classification

# %%
## Generate a dataset

X,y=make_classification(n_samples=1000,n_redundant=0,n_features=2,n_clusters_per_class=1,
                   weights=[0.90],random_state=12)

# %%
import pandas as pd
df1=pd.DataFrame(X,columns=['f1','f2'])
df2=pd.DataFrame(y,columns=['target'])
final_df=pd.concat([df1,df2],axis=1)

# %%
final_df
# Out:
#            f1        f2  target
# 0   -0.762898 -0.706808       0
# 1   -1.075436 -1.051162       0
# 2   -0.610115 -0.909802       0
# 3   -2.023284 -0.428945       1
# 4   -0.812921 -1.316206       0
# ..        ...       ...     ...
# 995 -0.712495 -0.880452       0
# 996 -2.625830 -2.827891       0
# 997 -1.326439 -1.815178       0
# 998 -0.833486 -0.514647       0
# 999 -0.302876 -0.575975       0
#
# [1000 rows x 3 columns]

# %%
final_df.head()
# Out:
#          f1        f2  target
# 0 -0.762898 -0.706808       0
# 1 -1.075436 -1.051162       0
# 2 -0.610115 -0.909802       0
# 3 -2.023284 -0.428945       1
# 4 -0.812921 -1.316206       0

# %%
final_df['target'].value_counts()
# Out:
# target
# 0    900
# 1    100
# Name: count, dtype: int64

# %% [markdown]
# ### OBSERVATIONS:
#
# 1. The above dataset is an imbalance dataset as it has 900 datapoints of target 0 and 100 datapoints of target 1.

# %%
### plot the imbalanced dataset

import matplotlib.pyplot as plt

plt.scatter(final_df['f1'], final_df['f2'], c = final_df['target'])

# %% [markdown]
# ## OBSERVATIONS:
#
# (i)  Here Category 'yellow' is very less in number as compared to 'Purple' color.

# %%
# !pip install imblearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
X.shape
# Out:
# (1000, 2)

# %%
y.shape
# Out:
# (1000,)

# %%
### Create SMOTE to address the imbalance dataset

from imblearn.over_sampling import SMOTE

#### Create an object for SMOTE

oversample = SMOTE()


### use the SMOTE to address the imbalance datasets

X,y=oversample.fit_resample(final_df[['f1','f2']],final_df['target'])

# %%
X
# Out:
#             f1        f2
# 0    -0.762898 -0.706808
# 1    -1.075436 -1.051162
# 2    -0.610115 -0.909802
# 3    -2.023284 -0.428945
# 4    -0.812921 -1.316206
# ...        ...       ...
# 1795 -1.095673  0.870580
# 1796 -1.487470  0.832848
# 1797 -0.741286  1.547403
# 1798 -1.360047  1.057458
# 1799 -1.634303  0.287700
#
# [1800 rows x 2 columns]

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 1795    1
# 1796    1
# 1797    1
# 1798    1
# 1799    1
# Name: target, Length: 1800, dtype: int64

# %%
df1 = pd.DataFrame(X)

# %%
df2 = pd.DataFrame(y,columns=['target'])

# %%
df1
# Out:
#             f1        f2
# 0    -0.762898 -0.706808
# 1    -1.075436 -1.051162
# 2    -0.610115 -0.909802
# 3    -2.023284 -0.428945
# 4    -0.812921 -1.316206
# ...        ...       ...
# 1795 -1.095673  0.870580
# 1796 -1.487470  0.832848
# 1797 -0.741286  1.547403
# 1798 -1.360047  1.057458
# 1799 -1.634303  0.287700
#
# [1800 rows x 2 columns]

# %%
df2
# Out:
#       target
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0
# ...      ...
# 1795       1
# 1796       1
# 1797       1
# 1798       1
# 1799       1
#
# [1800 rows x 1 columns]

# %%
oversample_df = pd.concat([df1,df2], axis=1)

# %%
oversample_df
# Out:
#             f1        f2  target
# 0    -0.762898 -0.706808       0
# 1    -1.075436 -1.051162       0
# 2    -0.610115 -0.909802       0
# 3    -2.023284 -0.428945       1
# 4    -0.812921 -1.316206       0
# ...        ...       ...     ...
# 1795 -1.095673  0.870580       1
# 1796 -1.487470  0.832848       1
# 1797 -0.741286  1.547403       1
# 1798 -1.360047  1.057458       1
# 1799 -1.634303  0.287700       1
#
# [1800 rows x 3 columns]

# %%
### plot the oversample dataset

import matplotlib.pyplot as plt

plt.scatter(oversample_df['f1'], oversample_df['f2'], c = oversample_df['target'])

# %% [markdown]
# ## OBSERVATIONS:
#
# (i) After oversampling, we came to know that the 'yellow' category number has increased as compared to the one before oversampling.
