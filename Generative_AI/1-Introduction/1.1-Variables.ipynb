# %% [markdown]
# ### Variables
#
# Variables are fundamental elements in programming used to store data that can be referenced and manipulated in a program. In Python, variables are created when you assign a value to them, and they do not need explicit declaration to reserve memory space. The declaration happens automatically when you assign a value to a variable.
#
# ### Video Outline:
#
# .   Introduction to Variables
#
# .   Declaring and Assigning Variables
#
# .   Naming Conventions
#
# .   Understanding Variable Types
#
# .   Type Checking and Conversion
#
# .   Dynamic Typing
#
# .   Practical Examples and Common Errors

# %%
#### Define the variable

var = 10

print(var)

print(type(var))
# Out:
# 10
# <class 'int'>

# %%
## Declaring And Assigning Variables

age=30

height= 5.8

name="Parag"

is_student=True

print("===================================Variables======================================================")

print(age)
print(height)
print(name)
print(is_student)


print("===================================Data Types======================================================")

print(type(age))
print(type(height))
print(type(name))
print(type(is_student))
# Out:
# ===================================Variables======================================================
# 30
# 5.8
# Parag
# True
# ===================================Data Types======================================================
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
## Naming Conventions
## Variable names should be descriptive
## They must start with a letter or an '_' and contains letter,numbers and underscores
## variables names case sensitive

#valid variable names


first_name = "Parag"

last_name  = "Pujari"

print(first_name)

print(last_name)
# Out:
# Parag
# Pujari

# %%
## case sensitivity

name = "Parag"

Name = "Pujari"

print(name)

print(Name)
# Out:
# Parag
# Pujari

# %% [markdown]
# #### OBSERVATIONS:
#
# 1.  As Python is case sensitive, it treats every word differently i.e in the above example name and Name are treated differently and both are not the same.

# %%
## Understnading Variable types
## Python is dynamically typed,type of a variable is determined at runtime
age=25 #int
height=6.1 #float
name="KRish" #str
is_student=True #bool

print("=========================================Variables========================================================")

print(age)
print(height)
print(name)
print(is_student)


print("=========================================Data  Types========================================================")

print(type(age))
print(type(height))
print(type(name))
print(type(is_student))
# Out:
# =========================================Variables========================================================
# 25
# 6.1
# KRish
# True
# =========================================Data  Types========================================================
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
## Type Checking and Conversion

type(height)
# Out:
# float

# %% [markdown]
# #### OBSERVATIONS;
#
# 1.  Python is dynamically typed and its data type and value gets changed during the run time of the execution of the program.

# %%
height = 7

print(height)

print(type(height))
# Out:
# 7
# <class 'int'>

# %%
age='25'
print(type(age))


x = int(age)

print(type(x))
# Out:
# <class 'str'>
# <class 'int'>

# %%
height=5.11
type(height)
# Out:
# float

# %%
float(int(height))
# Out:
# 5.0

# %%
#### Dynamic Typing ----->

##### Python supports dynamic typing as the data type of the variable gets changed during the run time execution of the program.


x = 10
print(x)
print(type(x))


x = 10.67
print(x)
print(type(x))
# Out:
# 10
# <class 'int'>
# 10.67
# <class 'float'>

# %%
## input

age=int(input("What is the age"))
print(age,type(age))
# Out:
# 30 <class 'int'>

# %%
### Simple calculator
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))


sums = num1 + num2
print("Sum of two numbers is:", sums)


diff = num1 - num2
print("Difference between two numbers is:", diff)


pro = num1 * num2
print("Product of two numbers is:", pro)


div = num1 / num2
print("Division of two numbers is:", div)
# Out:
# Sum of two numbers is: 11.0
# Difference between two numbers is: 9.0
# Product of two numbers is: 10.0
# Division of two numbers is: 10.0

# %% [markdown]
# #### Conclusion:
#
# Variables are essential in Python programming for storing and manipulating data. Understanding how to declare, assign, and use variables effectively is crucial for writing functional and efficient code. Following proper naming conventions and understanding variable types will help in maintaining readability and consistency in your code.
