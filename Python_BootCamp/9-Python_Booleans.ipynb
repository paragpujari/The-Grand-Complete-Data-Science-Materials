# %% [markdown]
# ## Boolean Values
#
# In programming you often need to know if an expression is True or False.
#
# You can evaluate any expression in Python, and get one of two answers, True or False.
#
# When you compare two values, the expression is evaluated and Python returns the Boolean answer:

# %%
print(10 > 9)

print(10 == 9)

print(10 < 9)
# Out:
# True
# False
# False

# %% [markdown]
# Print a message based on whether the condition is True or False:

# %%
a = 200
b = 33

if(a > b):
    print("a is greater than b:")
else:
    print("b is greater than a:")
# Out:
# a is greater than b:

# %% [markdown]
# ## Evaluate Values and Variables
#
# The bool() function allows you to evaluate any value, and give you True or False in return,

# %%
print(bool("Hello"))

print(bool(15))

print(bool("Parag"))

print(bool(9))
# Out:
# True
# True
# True
# True

# %%
print(bool(0))

print(bool(""))
# Out:
# False
# False

# %% [markdown]
# ### OBSERVATONS:
#
# 1.  It returns true for any number of string.
#
# 2.  It returns false for any 0 or "".

# %%
# Evaluate two variables:

x = "Hello"
y = 15

print(bool(x))

print(bool(y))
# Out:
# True
# True

# %% [markdown]
# ## Most Values are True
#
# Almost any value is evaluated to True if it has some sort of content.
#
# Any string is True, except empty strings.
#
# Any number is True, except 0.
#
# Any list, tuple, set, and dictionary are True, except empty ones.

# %%
bool(126)
# Out:
# True

# %%
bool("abc")
# Out:
# True

# %%
bool([10,30.6,"python",3+8j])
# Out:
# True

# %%
bool({10,20,30})
# Out:
# True

# %%
bool({'a':10,'b':20,'c':30})
# Out:
# True

# %% [markdown]
# ## Some Values are False
#
# In fact, there are not many values that evaluate to False, except empty values, such as (), [], {}, "", the number 0, and the value None. And of course the value False evaluates to False.

# %%
# empty strings
print(bool(""))

# empty numbers
print(bool(0))

# empty list
print(bool([]))

# empty tuple
print(bool(tuple()))

# empty sets
print(bool(set()))

# empty dictionary
print(bool(dict()))
# Out:
# False
# False
# False
# False
# False
# False

# %%
class myclass:
    def __len__(self):
        return(0)

# create the object for the class
myobj = myclass()
print(bool(myobj))
# Out:
# False

# %% [markdown]
# ## Functions can Return a Boolean
#
# You can create functions that returns a Boolean Value:

# %%
def myfunc():
    return(True)
    
myfunc()
# Out:
# True

# %%
def myfunc1():
    return(False)
    
myfunc1()
# Out:
# False

# %%
def myfunc():
    if(5 > 2):
        return(True)


myfunc()
# Out:
# True

# %% [markdown]
# isinstance() function => It can be used to determine if an object is of a certain data type:

# %%
x = 200

print(isinstance(x,int))
# Out:
# True
