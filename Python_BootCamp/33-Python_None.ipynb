# %% [markdown]
# ## Python None
#
# None is a special constant in Python that represents the absence of a value.
#
# Its data type is NoneType, and None is the only instance of a NoneType object

# %%
# Assign and display a None value

x = None

print(x)

print(type(x))
# Out:
# None
# <class 'NoneType'>

# %% [markdown]
# ## Comparing to None
#
# To compare a value to None, use the identity operator is or is not

# %%
x = None

if(x is None):
    print("None of the results is published.")
else:
    print("Results are published.")
# Out:
# None of the results is published.

# %%
x = None 

if(x is not None):
    print("No results are found:")
else:
    print("Results are displayed")
# Out:
# Results are displayed

# %% [markdown]
# ## True or False
#
# None evaluates to False in a boolean context

# %%
x = None

bool(x)
# Out:
# False

# %%
not(bool(x))
# Out:
# True

# %% [markdown]
# ## Functions returning None
#
# Functions that do not explicitly return a value return None by default

# %%
# function definition
def myfunc():
    x = 5
    
# function call
x = myfunc()

print(x)
# Out:
# None
