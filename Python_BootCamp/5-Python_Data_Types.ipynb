# %% [markdown]
# ### DataTypes
#
# 1. Definition:
#
# Data types are a classification of data which tell the compiler or interpreter how the programmer intends to use the data.
# They determine the type of operations that can be performed on the data, the values that the data can take, and the amount of memory needed to store the data.
#
# 2. Importance of Data Types in Programming
#
# Explanation:
#
# Data types ensure that data is stored in an efficient way.
# They help in performing correct operations on data.
# Proper use of data types can prevent errors and bugs in the program.
#
# ### Video Outline:
#
# 1.   Introduction to Data Types
#
# 2.   Importance of Data Types in Programming
#
# 3.   Basic Data Types
#
# 4.   Integers
#
# 5.   Floating-point numbers
#
# 6.   Strings
#
# 7.   Booleans
#
# 8.   Advanced Data Types
#
# 9.   Lists
#
# 10.  Tuples
#
# 11.  Sets
#
# 12.  Dictionaries
#
# 13.  Type Conversion

# %% [markdown]
# ## Data Types
#
# It helps in assigning the type to every data element in Python.

# %% [markdown]
# ### 1. Integer DataTypes

# %%
## Integer Example

age = 30

print(age)
# Out:
# 30

# %%
### Type of the Age

print(type(age))
# Out:
# <class 'int'>

# %%
x = 11

print(x)
# Out:
# 11

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
type(4)
# Out:
# int

# %%
type(-1)
# Out:
# int

# %%
type(0)
# Out:
# int

# %% [markdown]
# ### 2. Floating point DataTypes

# %%
## floating point datatype

height = 5.18

print(height)

print(type(height))
# Out:
# 5.18
# <class 'float'>

# %%
y = 2.14

print(y)

print(type(y))
# Out:
# 2.14
# <class 'float'>

# %%
type(1.0)
# Out:
# float

# %%
type(0.5)
# Out:
# float

# %%
type(0.56)
# Out:
# float

# %% [markdown]
# ## Converting from one object type to a different object type
#
# You can change the type of the object in Python; this is called typecasting. For example, you can convert an integer into a float (e.g. 2 to 2.0).
#
# Let's try it:

# %%
# Verify that this is an integer

type(2)
# Out:
# int

# %% [markdown]
# ## Converting integers to floats
#
# Let's cast integer 2 to float:

# %%
float(2)
# Out:
# 2.0

# %% [markdown]
# # Convert integer 2 to a float and check its type

# %%
type(float(2))
# Out:
# float

# %%
# Casting 1.1 to integer will result in loss of information

int(1.1)
# Out:
# 1

# %% [markdown]
# ## Converting from strings to integers or floats
#
# Sometimes, we can have a string that contains a number within it. If this is the case, we can cast that string that represents a number into an integer using int():

# %%
# Convert a string into an integer

int('1')
# Out:
# 1

# %%
# Convert a string into an integer with error

## int('1 or 2')

# %%
# Convert the string "1.2" into a float

float("1.2")
# Out:
# 1.2

# %% [markdown]
# ## Converting numbers to strings
#
# If we can convert strings to numbers, it is only natural to assume that we can convert numbers to strings, right?

# %%
# Convert an integer to a string

str(1)
# Out:
# '1'

# %%
# Convert a float to a string

str(1.1)
# Out:
# '1.1'

# %% [markdown]
# ### 3. String  DataTypes

# %%
## string datatype example

name = "Parag"

text = "Hello, Python 101 !"


print(name)

print(type(name))
# Out:
# Parag
# <class 'str'>

# %%
print(text)

print(type(text))
# Out:
# Hello, Python 101 !
# <class 'str'>

# %% [markdown]
# ### 4.  Boolean datatype

# %%
###  boolean datatype

is_true = True

print(is_true)

is_False = False

print(is_False)
# Out:
# True
# False

# %%
print(type(is_true))
# Out:
# <class 'bool'>

# %%
print(type(is_False))
# Out:
# <class 'bool'>

# %% [markdown]
# We can cast boolean objects to other data types. If we cast a boolean with a value of True to an integer or float we will get a one. If we cast a boolean with a value of False to an integer or float we will get a zero. Similarly, if we cast a 1 to a Boolean, you get a True. And if we cast a 0 to a Boolean we will get a False. Let's give it a try:

# %%
### Convert True to int

int(True)
# Out:
# 1

# %%
### Convert 1 to boolean

bool(1)
# Out:
# True

# %%
### Convert False to int

int(False)
# Out:
# 0

# %%
### Convert 0 to boolean

bool(0)
# Out:
# False

# %%
result = "Hello" + str(5)

# %%
result
# Out:
# 'Hello5'

# %% [markdown]
# ### 5. Lists

# %%
lists = [1,2,3,4,5]

print(lists)

print(type(lists))
# Out:
# [1, 2, 3, 4, 5]
# <class 'list'>

# %% [markdown]
# ### 6. Tuples

# %%
tuples = (1,2,3,4,5)

print(tuples)

print(type(tuples))
# Out:
# (1, 2, 3, 4, 5)
# <class 'tuple'>

# %% [markdown]
# ### 7. Sets

# %%
sets = {1,1,2,2,2,3,3,3,4,4,4,5,5,5}

print(tuples)

print(type(tuples))
# Out:
# (1, 2, 3, 4, 5)
# <class 'tuple'>

# %% [markdown]
# ### 8. Dictionaries

# %%
dicts = {'name':"parag"  ,
        'age' : 30       ,
        'salary' : 52345
        }

print(dicts)

print(type(dicts))
# Out:
# {'name': 'parag', 'age': 30, 'salary': 52345}
# <class 'dict'>

# %% [markdown]
# ## Exercise: Types
#
# 1.   What is the data type of the result of: 6 / 2?

# %%
print(type(6/2))
# Out:
# <class 'float'>

# %% [markdown]
# 2. What is the type of the result of: 6 // 2? (Note the double slash //.)

# %%
print(type(6//2))
# Out:
# <class 'int'>

# %% [markdown]
# 3. What is the type of the result of: "Hello, World!"

# %%
print(type("Hello, World!"))
# Out:
# <class 'str'>

# %% [markdown]
# 4. What is the type of the result of: "hello" == "world"

# %%
print(type("hello" == "world"))
# Out:
# <class 'bool'>

# %% [markdown]
# 5.  Write the code to convert the following number representing employeeid "1001" to an integer

# %%
employeeid = "1001"

print(int(employeeid))
# Out:
# 1001

# %% [markdown]
# 6. Write the code to convert this number representing financial value "1234.56" to a floating point number

# %%
x = "1234.56"

float(x)
# Out:
# 1234.56

# %% [markdown]
# 7. Write the code to convert this phone number 123-456-7890 to a string

# %%
phone_number = '123-456-7890'

str(phone_number)
# Out:
# '123-456-7890'
