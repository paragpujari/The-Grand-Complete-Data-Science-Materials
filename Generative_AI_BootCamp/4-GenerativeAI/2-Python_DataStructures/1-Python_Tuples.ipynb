# %% [markdown]
# ### Tuples:
#
# 1.  A Tuple is a data structure that contains the multiple items in a single variable.
#
# 2.  It is ordered.
#
# 3.  It is immutable.
#
# 4.  It contains the elements of same or different types.
#
# 5.  It can be indexed and contains all the duplicate elements.

# %%
#### empty tuple

tuples = ()

print(tuples)

print(type(tuples))
# Out:
# ()
# <class 'tuple'>

# %%
### Tuple with one element

tuples = (10,)

print(tuples)

print(type(tuples))
# Out:
# (10,)
# <class 'tuple'>

# %%
#### Tuples are ordered

tuples = (20,10,50,40,30)

print(tuples)

print(type(tuples))
# Out:
# (20, 10, 50, 40, 30)
# <class 'tuple'>

# %%
print(tuples[0])

print(tuples[1])

print(tuples[2])

print(tuples[3])

print(tuples[4])
# Out:
# 20
# 10
# 50
# 40
# 30

# %% [markdown]
# #### OBSERVATIONS:
#
# 1.  The way in which the elements is inserted into the tuple, the same element is printed out from the tuple. So the tuple follows a same order.
#
# 2.  Every element in the tuple has a fixed index position.

# %%
### Tuples are immutable

tuples[0] = 60

print(tuples)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 3
#       1 ### Tuples are immutable
# ----> 3 tuples[0] = 60
#       5 print(tuples)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# #### OBSERVATIONS:
#
# 1.  The elements in the tuples cannot be changed as the tuple object does not item assignment.

# %%
### It contains the elements of same or different types

tuples = (20,10,30.98,True,(8+9j),'Parag')


print(tuples)
# Out:
# (20, 10, 30.98, True, (8+9j), 'Parag')

# %% [markdown]
# #### OBSERVATIONS:
#
# 1.  The elements in the above tuple contains the elements of integer, float, boolean, complex and string.

# %%
### Tuples also contains duplicates

tuples = (10,10,20,20,20,30,30,40,50)

# %%
print(tuples)
# Out:
# (10, 10, 20, 20, 20, 30, 30, 40, 50)

# %% [markdown]
# #### OBSERVATIONS:
#
# 1.  There are duplicates present in the tuples.

# %% [markdown]
# #### Tuple len
#
# len() ------------->  It helps in determining the length of the tuple.

# %%
tuples = (10,10,20,20,20,30,30,40,50)


print("Length of the tuple is:", len(tuples))
# Out:
# Length of the tuple is: 9

# %%
tuples = ("apple","banana","cherry")

l = len(tuples)

print("Length of the tuple is:", l)
# Out:
# Length of the tuple is: 3

# %% [markdown]
# ### Create Tuple With One Item
#
# To create a tuple with only one item, you have to add a comma after the item, otherwise Python will not recognize it as a tuple.

# %%
tuples = ("apple")

print(tuples)

print(type(tuples))
# Out:
# apple
# <class 'str'>

# %%
#### Tuple

tuples = ("apple",)

print(tuples)

print(type(tuples))
# Out:
# ('apple',)
# <class 'tuple'>

# %% [markdown]
# #### Data Types in the tuples

# %%
tuple1 = ("disco",10,1.2 )

print(type(tuple1[0]))
print(type(tuple1[1]))
print(type(tuple1[2]))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# #### OBSERVATIONS:
#
# 1.  The first  element in the tuple is of the type 'string'.
#
# 2.  The second element in the tuple is of the type 'integer'.
#
# 3.  The third  element in the tuple is of the type 'float'.

# %%
# It can have the elements of different types in it

tuple1 = ("abc", 34, True, 40, "male",(3+4j), 78.34)

print(tuple1)

print(type(tuple1))
# Out:
# ('abc', 34, True, 40, 'male', (3+4j), 78.34)
# <class 'tuple'>

# %% [markdown]
# ### The tuple() Constructor
#
# It is also possible to use the tuple() constructor to make a tuple

# %%
mytuples = tuple(("apple","banana","cherry"))

print(mytuples)

print(type(mytuples))
# Out:
# ('apple', 'banana', 'cherry')
# <class 'tuple'>

# %% [markdown]
# #### Access the elements in the tuple

# %%
print(mytuples[0])

print(mytuples[1])

print(mytuples[2])
# Out:
# apple
# banana
# cherry

# %%
print(mytuples[-1])

print(mytuples[-2])

print(mytuples[-3])
# Out:
# cherry
# banana
# apple

# %% [markdown]
# ### Slicing
#
# We can slice tuples, obtaining new tuples with the corresponding elements:

# %%
mytuples = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")

print(mytuples)

# Slice from index 0 to index 2

print(mytuples[0:3])

# Slice from index 3 to index 4

print(mytuples[3:5])

# Return the third, fourth, and fifth item

print(mytuples[2:5])
# Out:
# ('apple', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango')
# ('apple', 'banana', 'cherry')
# ('orange', 'kiwi')
# ('cherry', 'orange', 'kiwi')

# %%
# This example returns the items from the beginning to, but NOT included, "kiwi"

print(mytuples[0:4])
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %%
# This example returns the items from "cherry" and to the end

print(mytuples[2:])
# Out:
# ('cherry', 'orange', 'kiwi', 'melon', 'mango')

# %%
# This example returns the items from index -4 (included) to index -1 

mytuples[-4:]
# Out:
# ('orange', 'kiwi', 'melon', 'mango')

# %%
# This example returns the items from index -4 (included) to index -1 excluded

mytuples[-4:-1]
# Out:
# ('orange', 'kiwi', 'melon')

# %% [markdown]
# ### Check if Item Exists
#
# To determine if a specified item is present in a tuple use the in keyword:

# %%
thistuple = ("apple", "banana", "cherry")

if("apple" in thistuple):
    print('apple is present in the tuple')
# Out:
# apple is present in the tuple

# %% [markdown]
# ### Python - Update Tuples
#
# Tuples are unchangeable, meaning that you cannot change, add, or remove items once the tuple is created.
#
# But there are some workarounds.
#
# Change Tuple Values Once a tuple is created, you cannot change its values. Tuples are unchangeable, or immutable as it also is called.
#
# But there is a workaround. You can convert the tuple into a list, change the list, and convert the list back into a tuple

# %%
x = ("apple", "banana", "cherry")

print(x)

y = x

print(y)

### Tuples are immutable as the elements in the tuple cannot be changed

# y[1] = "guava"

print(y)
# Out:
# ('apple', 'banana', 'cherry')
# ('apple', 'banana', 'cherry')
# ('apple', 'banana', 'cherry')

# %% [markdown]
# #### OBSERVATIONS:
#
# 1.  If we try to modify the element in the tuple, then it will throw an error showing 'item assignment'.

# %% [markdown]
# ### Add Items
#
# Since tuples are immutable, they do not have a built-in append() method, but there are other ways to add items to a tuple.
#
# Convert into a list: Just like the workaround for changing a tuple, you can convert it into a list, add your item(s), and convert it back into a tuple.

# %%
### Tuple

print(x)

tuples = x

print(tuples)


### To modify the element in the tuple, convert it into the list

l = list(tuples)

print(l)

#### Modify the element in the list

l[2] = 'guava'

print(l)

#### Convert the list back into the tuple

tup = tuple(l)

print(tup)
# Out:
# ('apple', 'banana', 'cherry')
# ('apple', 'banana', 'cherry')
# ['apple', 'banana', 'cherry']
# ['apple', 'banana', 'guava']
# ('apple', 'banana', 'guava')

# %% [markdown]
# #### OBSERVATIONS:
#
# 1.  In this way, we have modified the elements in the tuple.

# %%
#### Add the element "mango" in the tuple
tup = tup + ("mango",)

# %%
tup
# Out:
# ('apple', 'banana', 'guava', 'mango')

# %% [markdown]
# ### Remove Items
#
# Note: You cannot remove items in a tuple.
#
# Tuples are unchangeable, so you cannot remove items from it, but you can use the same workaround as we used for changing and adding tuple items:

# %%
### Tuple

print(tup)


#### Remove the element 'banana' from the tuple

l = list(tup)

print(l)

l.remove('banana')

print(l)

#### Convert the list back to tuple

tup = tuple(l)

print(tup)
# Out:
# ('apple', 'banana', 'guava', 'mango')
# ['apple', 'banana', 'guava', 'mango']
# ['apple', 'guava', 'mango']
# ('apple', 'guava', 'mango')

# %%
# The del keyword can delete the tuple completely

del tup

# %%
print(tup)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 print(tup)
#
# NameError: name 'tup' is not defined

# %% [markdown]
# #### OBSERVATIONS:
#
# 1. del removes the entire tuple .

# %% [markdown]
# ### Unpacking a Tuple
#
# When we create a tuple, we normally assign values to it. This is called "packing" a tuple
#
# But, in Python, we are also allowed to extract the values back into variables. This is called "unpacking

# %%
res = ('apple', 'banana', 'cherry', 'orange', 'guava')


print(res)
# Out:
# ('apple', 'banana', 'cherry', 'orange', 'guava')

# %%
a,b,c,d,e = res

print(a)
print(b)
print(c)
print(d)
print(e)
# Out:
# apple
# banana
# cherry
# orange
# guava

# %% [markdown]
# ### Using Asterisk*
#
#
# If the number of variables is less than the number of values, you can add an * to the variable name and the values will be assigned to the variable as a list:

# %%
fruits = ("apple", "banana", "cherry", "strawberry", "raspberry")

x,*y,z = fruits

print(x)
print(*y)
print(z)
# Out:
# apple
# banana cherry strawberry
# raspberry

# %%
fruits = ("apple", "mango", "papaya", "pineapple", "cherry")

x,*y,z = fruits

print(x)
print(*y)
print(z)
# Out:
# apple
# mango papaya pineapple
# cherry

# %% [markdown]
# ### Python - Loop Tuples
#
# ### Loop Through a Tuple
#
# You can loop through the tuple items by using a for loop.

# %%
fruits = ("apple", "banana", "cherry", "strawberry", "raspberry")


for x in fruits:
    print(x)
# Out:
# apple
# banana
# cherry
# strawberry
# raspberry

# %%
l = len(fruits)

print(l)

for i in range(l):
    print(fruits[i])
# Out:
# 5
# apple
# banana
# cherry
# strawberry
# raspberry

# %%
for i in range(l):
    print(i, fruits[i])
# Out:
# 0 apple
# 1 banana
# 2 cherry
# 3 strawberry
# 4 raspberry

# %%
# Print all items, using a while loop to go through all the index numbers:


l = len(fruits)
i = 0
while(i < l):
    print(i, fruits[i])
    i = i + 1
# Out:
# 0 apple
# 1 banana
# 2 cherry
# 3 strawberry
# 4 raspberry

# %% [markdown]
# ### Python - Join Tuples
#
# ### Join Two Tuples
#
# To join two or more tuples you can use the + operator:

# %%
a = ("apple","banana","cherry")

b = ("guava", "strawberry", "papaya")

c = a + b

print(c)
# Out:
# ('apple', 'banana', 'cherry', 'guava', 'strawberry', 'papaya')

# %% [markdown]
# #### Methods in Tuples:

# %%
# 1. count() = returns the number of times a specified value appears in the tuple


thistuple = (1, 3, 7, 8, 7, 5, 4, 6, 8, 5)

x = thistuple.count(5)

print("Occurence of the element 5 is:", x)
# Out:
# Occurence of the element 5 is: 2

# %%
# 2. index() = It searches for the first occurrence of the value  and return its position

thistuple = (1, 3, 7, 8, 7, 5, 4, 6, 8, 5)

x = thistuple.index(7)

print("Index of the element 7 in the tuple is:", x)
# Out:
# Index of the element 7 in the tuple is: 2
