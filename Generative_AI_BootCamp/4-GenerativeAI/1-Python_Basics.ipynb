# %% [markdown]
# ### Python:
#
# 1.  It is an open source and general purpose programming language.
#
# 2.  It is an object oriented programming language.
#
# 3.  It is used for scripting tasks.
#
# 4.  It is used for data science and analytics roles.
#
# 5.  It is very easy to learn and use.
#
# 6.  It has a strong supported library.
#
# 7.  It has a cross platform language.
#
# 8.  It is an interpreted language and is extensible.
#
# 9.  It is more user friendly and is one of the most stable languages.
