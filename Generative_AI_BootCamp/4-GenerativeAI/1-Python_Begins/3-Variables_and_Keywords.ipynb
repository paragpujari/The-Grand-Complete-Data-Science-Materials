# %% [markdown]
# ### Variables
#
# These are the placeholder that is used to store the values for an entity.

# %%
a = 'Hello World'

print("=====================Variable and the data type of the element=======================================")

print(a)

print(type(a))
# Out:
# =====================Variable and the data type of the element=======================================
# Hello World
# <class 'str'>

# %%
age = 30

print("=====================Variable and the data type of the element=======================================")

print(age)

print(type(age))
# Out:
# =====================Variable and the data type of the element=======================================
# 30
# <class 'int'>

# %%
print("=====================Variable and the data type of the element=======================================")

score = 89.5

print(score)

print(type(score))
# Out:
# =====================Variable and the data type of the element=======================================
# 89.5
# <class 'float'>

# %%
print("=====================Variable and the data type of the element=======================================")

score = '10.5'

print(score)

print(type(score))
# Out:
# =====================Variable and the data type of the element=======================================
# 10.5
# <class 'str'>

# %%
print("=====================Variable and the data type of the element=======================================")

var = True

print(var)

print(type(var))
# Out:
# =====================Variable and the data type of the element=======================================
# True
# <class 'bool'>

# %%
 #### 5a = 10       --------------> Variable cannot start with the number.

# %%
strings = "hello text 123"

print(strings)

print(type(strings))
# Out:
# hello text 123
# <class 'str'>

# %%
name = 2
Name = 4

print(name)

print(Name)
# Out:
# 2
# 4

# %% [markdown]
# #### OBSERVATIONS:
#
# 1.  Both name and Name are case sensitive and is treated differently.

# %%
##### Function calling

def sum(x,y):
    return(x+y)

a = sum(12,13)
print(a)
# Out:
# 25

# %%
name = "Parag"
age  =  30
gender = "Male"
address = "Sambalpur"

print(name)
print(age)
print(gender)
print(address)


print(type(name))
print(type(age))
print(type(gender))
print(type(address))
# Out:
# Parag
# 30
# Male
# Sambalpur
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# ##### OBSERVATIONS:
#
# 1.  continue, print, def, type, if etc are the special reserved keywords and is used for a specific purpose in the program.
