# %% [markdown]
# ### Inheritance:
#
# It refers to the property of acquiring the properties of the child class from the parent class.

# %% [markdown]
# ### super()
#
# It is used to inherit the constructor of the parent class to initailize all the member variables.

# %%
class Car:
    ### initialize the constructor to initialize the data members of the class
    def __init__(self,windows,doors,enginetype):
        self.windows = windows
        self.doors   = doors
        self.enginetype = enginetype

    def print_details(self):
        print("Windows    used in the car is:", + self.windows)
        print("doors      used in the car is:",   + self.doors)
        print("enginetype used in the car is:", + self.enginetype)


class Audi(Car):
    ### use the init contructor to inherit the properties from the car class along with horsepower
    def __init__(self,windows,doors,enginetype,horsepower):
        super().__init__(windows,doors,enginetype)
        self.horsepower = horsepower


    def print_details(self):
        print("Windows    used in the car is:", + self.windows)
        print("doors      used in the car is:",   + self.doors)
        print("enginetype used in the car is:", + self.enginetype)
        print("horse power used in the Car is:", + self.horsepower)


a = Audi(4,5,"Diesel", 200)
print(a.windows)
print(a.doors)
print(a.enginetype)
print(a.horsepower)
# Out:
# 4
# 5
# Diesel
# 200

# %% [markdown]
# ### Single Level Inheritance :
#
# It refers to the process of acquiring the properties of the child class from the parent class directly.

# %%
### define the parent class

class Parent:
    def print_parent_details(self):
        print("Parent Class Details:")

class Child(Parent):
    def print_child_details(self):
        print("Child Class Details:")

ch = Child()
ch.print_child_details()
ch.print_parent_details()
# Out:
# Child Class Details:
# Parent Class Details:

# %%
# Addition of two numbers using Single level Inheritance

class Numbers:
    def enter_numbers(self,x,y):
        self.a = x
        self.b = y

    def print_numbers(self):
        print("First Numbers is:", self.a)
        print("Second umbers is:", self.b)

class Sum(Numbers):
    def calc_total_numbers(self):
        print("Sum of two numbers is:", (self.a + self.b))


obj = Sum()
obj.enter_numbers(10,10)
obj.print_numbers()
obj.calc_total_numbers()
# Out:
# First Numbers is: 10
# Second umbers is: 10
# Sum of two numbers is: 20

# %% [markdown]
# ### Multi Level Inheritance:
#
# It refers to the process of acquiring the properties of one class into another class.

# %%
class Num1:
    def enter_first_number(self,x):
        self.num1 = x

    def print_first_number(self):
        print("First Number is:", self.num1)

class Num2(Num1):
    def enter_second_number(self,y):
        self.num2 = y

    def print_second_number(self):
        print("Second Number is:", self.num2)

class Sum(Num2):
    def calc_total(self):
        print("Sum of two numbers is:", (self.num1 + self.num2))


s = Sum()
s.enter_first_number(10)
s.print_first_number()

s.enter_second_number(10)
s.print_second_number()

s.calc_total()
# Out:
# First Number is: 10
# Second Number is: 10
# Sum of two numbers is: 20

# %% [markdown]
# ### Multiple Inheritance:
#
# It refers to the process when the class inherits from more than one parent class.

# %%
class Num1:
    def enter_first_number(self,x):
        self.num1 = x

    def print_first_number(self):
        print("First Number is:", self.num1)

class Num2:
    def enter_second_number(self,y):
        self.num2 = y

    def print_second_number(self):
        print("Second Number is:", self.num2)

class Sum(Num1, Num2):
    def calc_total(self):
        print("Sum of two numbers is:", (self.num1 + self.num2))

obj = Sum()
obj.enter_first_number(10)
obj.print_first_number()

obj.enter_second_number(10)
obj.print_second_number()

obj.calc_total()
# Out:
# First Number is: 10
# Second Number is: 10
# Sum of two numbers is: 20

# %% [markdown]
# ### Hierarchical Inheritance
#
# It refers to the process when multiple number of classes gets inherited from the same base class.

# %%
class Numbers:
    def enter_numbers(self,x,y):
        self.num1 = x
        self.num2 = y

    def print_numbers(self):
        print("First  Number is:", self.num1)
        print("Second Number is:", self.num2)

class Addition(Numbers):
    def calc_total(self):
        print("Addition of two numbers is:", (self.num1 + self.num2))

class Substraction(Numbers):
    def calc_diff(self):
        print("Substraction between two numbers is:", (self.num1 - self.num2))

class Multiplication(Numbers):
    def calc_product(self):
        print("Product of two numbers is:", (self.num1 * self.num2))

class Division(Numbers):
    def calc_divide(self):
        print("Division of two numbers is:", (self.num1 / self.num2))

obj = Numbers()
obj.enter_numbers(10,10)
obj.print_numbers()

add = Addition()
add.enter_numbers(10,10)
add.calc_total()

Sub = Substraction()
Sub.enter_numbers(10,10)
Sub.calc_diff()

mul = Multiplication()
mul.enter_numbers(10,10)
mul.calc_product()


div = Division()
div.enter_numbers(10,10)
div.calc_divide()
# Out:
# First  Number is: 10
# Second Number is: 10
# Addition of two numbers is: 20
# Substraction between two numbers is: 0
# Product of two numbers is: 100
# Division of two numbers is: 1.0
