# %% [markdown]
# ### Encapsulation In Python
#
#
# Encapsulation is a fundamental principle in object-oriented programming that focuses on bundling data and the methods that operate on that data into a single unit called a class.
#
# It allows you to control the access and visibility of the data and methods, providing a way to protect and organize your code.
#
# It refers to the process of wrapping up of data and information in a single entity.
#
# It keeps all the data and information in a single entity called class and keeps it confidential from the outside world.
#
# It keeps the data members and member functions as private

# %%
### Protected

class Person:
    ### initialize the constructor
    def __init__(self,n,a,s):
        self._name = n
        self._age  = a
        self._salary = s

    def _print_details(self):
        print("Name is:", self._name)
        print("Age is:", self._age)
        print("Salry is:", self._salary)

p = Person("Parag",30,52345)
p._print_details()
# Out:
# Name is: Parag
# Age is: 30
# Salry is: 52345

# %% [markdown]
# ### OBSERVATIONS:
#
# 1. As the data members and the member function are beginning with '_'. So it is considered as Protected.
#
# 2. Using the Protected, the data members and the meber functions can be called using the object.

# %%
### Private

class Person:
    ### initialize the constructor
    def __init__(self,n,a,s):
        self.__name = n
        self.__age  = a
        self.__salary = s

    def __print_details(self):
        print("Name is:", self.__name)
        print("Age is:", self.__age)
        print("Salry is:", self.__salary)

p = Person("Parag",30,52345)
p._print_details()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 16
#      13         print("Salry is:", self.__salary)
#      15 p = Person("Parag",30,52345)
# ---> 16 p._print_details()
#
# AttributeError: 'Person' object has no attribute '_print_details'

# %% [markdown]
# ### OBSERVATIONS:
#
# 1. As the data members and the member function are beginning with '__'. So it is considered as Private.
#
# 2. Using the Private, the data members and the meber functions cannot be called using the object.
