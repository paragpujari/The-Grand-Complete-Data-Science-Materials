# %%
# %pip install streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st

# %% [markdown]
# ### Streamlit
#
# 1. A streamlit is an open source python library that is used to create beautiful web applications and interfaces for data science applications.
#
# 2. It is easy to use.
#
# 3. It has fast developments
#
# 4. It has intercative UI elements.
#
# 5. Great for Data science as it suppports pandas, matplotlib, Plotly and other libraries.
#
# 6. Deployment is also very easy.
