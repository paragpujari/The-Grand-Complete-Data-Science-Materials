# %% [markdown]
# ### The map() Function in Python
#
# The map() function applies a given function to all items in an input list (or any other iterable) and returns a map object (an iterator). This is particularly useful for transforming data in a list comprehensively.

# %%
### Find out the square of all the elements in the list

numbers=[1,2,3,4,5,6,7,8]

res = list(map(lambda x:x ** 2,numbers))

print(res)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64]

# %%
### Map multiple iterables

numbers1=[1,2,3]
numbers2=[4,5,6]


### add each element from both the lists

res = list(map(lambda x,y:x+y,numbers1,numbers2))

print(res)
# Out:
# [5, 7, 9]

# %%
# Use map to convert strings to integers
str_numbers = ['1', '2', '3', '4', '5']

res = list(map(int,str_numbers))

print(res)
# Out:
# [1, 2, 3, 4, 5]

# %%
### Use map function to convert every word into upper case in the list

fruits = ['apple','banana','guava']

res = list(map(str.upper,fruits))

print(res)
# Out:
# ['APPLE', 'BANANA', 'GUAVA']

# %%
def get_name(person):
    return person['name']

people=[
    {'name':'Krish','age':32},
    {'name':'Jack','age':33}
]
list(map(get_name,people))
# Out:
# ['Krish', 'Jack']

# %% [markdown]
# ### Conclusion
#
# The map() function is a powerful tool for applying transformations to iterable data structures. It can be used with regular functions, lambda functions, and even multiple iterables, providing a versatile approach to data processing in Python. By understanding and utilizing map(), you can write more efficient and readable code.
