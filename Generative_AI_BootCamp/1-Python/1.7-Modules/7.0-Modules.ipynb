# %% [markdown]
# ### Modules:
#
# It refers to the set of functions that we want to include in our application.

# %%
import add

x = add.addition(2,3)

x
# Out:
# 5

# %%
import sub

x = sub.substraction(4,2)

x
# Out:
# 2

# %%
import mul

x = mul.product(3,4)

x
# Out:
# 12

# %%
import div

x = div.divide(10,2)

x
# Out:
# 5.0

# %%
import math

x = math.sqrt(16)

x
# Out:
# 4.0
