# %% [markdown]
# ### DataTypes
#
# #### 1. Definition:
#
# Data types are a classification of data which tell the compiler or interpreter how the programmer intends to use the data.
# They determine the type of operations that can be performed on the data, the values that the data can take, and the amount of memory needed to store the data.
#
# #### 2. Importance of Data Types in Programming
#
# (i)    Data types ensure that data is stored in an efficient way.
#
# (ii)   They help in performing correct operations on data.
#
# (iii)  Proper use of data types can prevent errors and bugs in the program.
#
#
# ###  Video Outline:
#
# (i)   Introduction to Data Types
#
# (ii)  Importance of Data Types in Programming
#
# (iii) Basic Data Types
#
#
#     (a.)   Integers
#
#     (b.)   Floating-point numbers
#
#     (c.)   Strings
#
#     (d.)   Booleans
#
# ### Advanced Data Types
#
#     (a.)   Lists
#
#     (b.)   Tuples
#
#     (c.)   Sets
#
#     (d.)   Dictionaries
#
# ###  Type Conversion
#
# ###  Practical Examples

# %%
## Integer Example

age = 30

print(age)

print(type(age))
# Out:
# 30
# <class 'int'>

# %%
## floating point datatype

height = 5.18

print(height)

print(type(height))
# Out:
# 5.18
# <class 'float'>

# %%
## string datatype example

name = "Parag"

print(name)

print(type(name))
# Out:
# Parag
# <class 'str'>

# %%
## boolean datatype

is_true = True

print(is_true)

print(type(is_true))
# Out:
# True
# <class 'bool'>

# %%
a = 10
b = 10

print(a == b)

print(type(a == b))
# Out:
# True
# <class 'bool'>

# %%
## common errors

#x = "Hello" + 5

#print(x)

# %%
x = "Hello" + str(5)

print(x)
# Out:
# Hello5

# %% [markdown]
# ### OBSERVATIONS:
#
# 1. Addition is possible only when both the elements are of the same type.
